# %% [markdown]
# <a href="https://colab.research.google.com/github/omamazainab/Deep-Learning-Excercises/blob/master/MNIST_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
if tf.__version__ != 2:
  # !pip install tensorflow==2.0.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
digit = train_images[4]
import matplotlib.pyplot as plt
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
train_images.shape #3D list
# Out:
# (60000, 28, 28)

# %%
 len(train_labels)
# Out:
# 60000

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
network = models.Sequential() #creating sequential model
network.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,))) # fully connected lyer
network.add(layers.Dense(10, activation='softmax')) # output lyer, it will return array of 10 probablity scores

# %%
network.compile(optimizer='rmsprop', 
loss='categorical_crossentropy',
metrics=['accuracy'])

# %%
#preparing image data
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
#preparing labels
from keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
#we fit the model to its training data
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.2578 - accuracy: 0.9250
# Epoch 2/5
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.1042 - accuracy: 0.9690
# Epoch 3/5
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0679 - accuracy: 0.9800
# Epoch 4/5
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.0495 - accuracy: 0.9846
# Epoch 5/5
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.0378 - accuracy: 0.9887

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...
